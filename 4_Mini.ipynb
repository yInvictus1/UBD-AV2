# %% [markdown]
# ---
#
# # 🩺 Minimundo 4 — Relação entre IMC e Pressão Arterial
#
# ## 📘 Contexto
#
# Uma clínica busca entender como a **idade** e o **índice de massa corporal (IMC)** se relacionam com a **pressão arterial sistólica** de seus pacientes.
#
# ---
#
# ## 🧩 Tarefas realizadas
#
# * Calcular médias e correlações entre **IMC** e **pressão arterial**
# * Gerar **gráfico de dispersão** (*idade × pressão*)
# * Criar **mapa de calor** com a **matriz de correlação**
#
# ---
#
# ## 🧰 Bibliotecas utilizadas
#
# * `pandas`
# * `seaborn`
#
# ---
#
# ## 📂 Arquivo base
#
# **pressao_arterial.csv**
#
# | paciente | idade | imc  | pressao_sistolica |
# | -------- | ----- | ---- | ----------------- |
# | 1        | 25    | 22.4 | 118               |
# | 2        | 40    | 27.1 | 132               |
# | 3        | 55    | 30.2 | 146               |
# | 4        | 65    | 31.8 | 155               |
# | 5        | 35    | 25.7 | 128               |
#
# ---

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Lendo arquivo
df = pd.read_csv("dados/pressao_arterial.csv")

# Calculando Média e correlação entre IMC e Pressão Arterial
Media_IMC = df['imc'].mean()
Media_Press = df['pressao_sistolica'].mean()
correlacao_imc = df['imc'].corr(df['pressao_sistolica'])
correlacao_idade = df['idade'].corr(df['pressao_sistolica'])

#Imprimindo Valores
print(f"Média do IMC: {Media_IMC:.2f}")
print(f"Média da pressão arterial: {Media_Press:.2f}")
print(f"Correlação entre IMC e Pressão arterial: {correlacao_imc:.2f}")
print(f"Correlação entre Idade e Pressão arterial: {correlacao_idade:.2f}")

# Criando gráfico de dispersão
sns.regplot(data=df, x="idade", y="pressao_sistolica")
plt.title("Gráfico de Dispersão entre Idade e Pressão Arterial")
plt.xlabel("Idade")
plt.ylabel("Pressão Arterial Sistólica (mmHg)")
plt.show()

# Criando matriz de correlação
matriz_corr = df.corr()

# Plotando o heatmap
fig, ax = plt.subplots(figsize=(10, 6))
sns.heatmap(matriz_corr, fmt='.2f', square=True, linecolor='white', annot=True, cmap="coolwarm")
plt.title("Matriz de Correlação - Todas as Variáveis")
plt.tight_layout()
plt.show()
# Out:
# Média do IMC: 27.44
# Média da pressão arterial: 135.80
# Correlação entre IMC e Pressão arterial: 0.99
# Correlação entre Idade e Pressão arterial: 1.00
